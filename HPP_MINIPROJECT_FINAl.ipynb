# %% [markdown]
# <a href="https://colab.research.google.com/github/vishnupriya-ms/My-Projects/blob/main/HPP_MINIPROJECT_FINAl.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#IMPORT BASIC LIBRARIES

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#IMPORT CSV FILE TO PANDAS

# %%
data=pd.read_csv("/content/House Data_Pune.csv")
data
# Out:
#                 area_type       location          Society   size  Baths  \
# 0     Super Built-up Area        Bavdhan     Satyam Shrey  2 bhk    2.0
# 1           Built-up Area            Sus  Kiran Sanskriti  2 bhk    2.0
# 2           Built-up Area      Tathawade          Vivanta  2 bhk    2.0
# 3     Super Built-up Area  Koregaon Park      Sunit Anant  3 bhk    3.0
# 4           Built-up Area   Sinhgad Road      Nanded city  3 bhk    3.0
# ...                   ...            ...              ...    ...    ...
# 1624                  NaN   Sinhgad Road              NaN  2 bhk    2.0
# 1625                  NaN  Koregaon Park              NaN  2 bhk    2.0
# 1626                  NaN       Swargate              NaN  1 bhk    1.0
# 1627                  NaN    Karve Nagar              NaN  3 bhk    3.0
# 1628                  NaN    Karve Nagar              NaN  2 bhk    2.0
#
#      total_sqft   price        availability  Unnamed: 8 Unnamed: 9
# ...

# %%
#REMOVE UNNECESSARY COLUMNS

# %%
data = data.drop(columns=['Unnamed: 8', 'Unnamed: 9'], errors='ignore')
data
# Out:
#                 area_type       location          Society   size  Baths  \
# 0     Super Built-up Area        Bavdhan     Satyam Shrey  2 bhk    2.0
# 1           Built-up Area            Sus  Kiran Sanskriti  2 bhk    2.0
# 2           Built-up Area      Tathawade          Vivanta  2 bhk    2.0
# 3     Super Built-up Area  Koregaon Park      Sunit Anant  3 bhk    3.0
# 4           Built-up Area   Sinhgad Road      Nanded city  3 bhk    3.0
# ...                   ...            ...              ...    ...    ...
# 1624                  NaN   Sinhgad Road              NaN  2 bhk    2.0
# 1625                  NaN  Koregaon Park              NaN  2 bhk    2.0
# 1626                  NaN       Swargate              NaN  1 bhk    1.0
# 1627                  NaN    Karve Nagar              NaN  3 bhk    3.0
# 1628                  NaN    Karve Nagar              NaN  2 bhk    2.0
#
#      total_sqft   price        availability
# 0           640   55.96  Under construction
# ...

# %%
data.columns
# Out:
# Index(['area_type', 'location', 'Society', 'size', 'Baths', 'total_sqft',
#        'price', 'availability'],
#       dtype='object')

# %%
data.size
# Out:
# 13032

# %%
data.shape
# Out:
# (1629, 8)

# %%
data.groupby('area_type')['area_type'].agg('count')
# Out:
# area_type
# Built-up  Area           56
# Built-up Area           175
# Built-up area             4
# Carpet Area               3
# Plot  Area               42
# Plot Area                21
# Super Built-up Area     152
# Super built-up  Area    193
# Villa                     1
# Name: area_type, dtype: int64

# %%
#TO KEEP MODEL SIMPLE WE DROP COLUMNS DOESNOT AFFECT MODEL

# %%
df=data.drop(['area_type','Society','availability'],axis=1)
df
# Out:
#            location   size  Baths total_sqft   price
# 0           Bavdhan  2 bhk    2.0        640   55.96
# 1               Sus  2 bhk    2.0   690-720    45.00
# 2         Tathawade  2 bhk    2.0   688-693    60.00
# 3     Koregaon Park  3 bhk    3.0       1659  210.00
# 4      Sinhgad Road  3 bhk    3.0       1450   78.00
# ...             ...    ...    ...        ...     ...
# 1624   Sinhgad Road  2 bhk    2.0       1175   73.50
# 1625  Koregaon Park  2 bhk    2.0       1425   80.00
# 1626       Swargate  1 bhk    1.0       1200   20.00
# 1627    Karve Nagar  3 bhk    3.0       1200   56.12
# 1628    Karve Nagar  2 bhk    2.0       1255   67.00
#
# [1629 rows x 5 columns]

# %%
df.isna().sum()
# Out:
# location       0
# size           3
# Baths         13
# total_sqft     1
# price          0
# dtype: int64

# %%
df.size
# Out:
# 8145

# %%
df=df.dropna()
df
# Out:
#            location   size  Baths total_sqft   price
# 0           Bavdhan  2 bhk    2.0        640   55.96
# 1               Sus  2 bhk    2.0   690-720    45.00
# 2         Tathawade  2 bhk    2.0   688-693    60.00
# 3     Koregaon Park  3 bhk    3.0       1659  210.00
# 4      Sinhgad Road  3 bhk    3.0       1450   78.00
# ...             ...    ...    ...        ...     ...
# 1624   Sinhgad Road  2 bhk    2.0       1175   73.50
# 1625  Koregaon Park  2 bhk    2.0       1425   80.00
# 1626       Swargate  1 bhk    1.0       1200   20.00
# 1627    Karve Nagar  3 bhk    3.0       1200   56.12
# 1628    Karve Nagar  2 bhk    2.0       1255   67.00
#
# [1616 rows x 5 columns]

# %%
df.isna().sum()
# Out:
# location      0
# size          0
# Baths         0
# total_sqft    0
# price         0
# dtype: int64

# %%
df['bhk']=df['size'].apply(lambda x: int(x.split(' ')[0]))
# Out:
# <ipython-input-105-09fa598f2bdb>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['bhk']=df['size'].apply(lambda x: int(x.split(' ')[0]))

# %%
df
# Out:
#            location   size  Baths total_sqft   price  bhk
# 0           Bavdhan  2 bhk    2.0        640   55.96    2
# 1               Sus  2 bhk    2.0   690-720    45.00    2
# 2         Tathawade  2 bhk    2.0   688-693    60.00    2
# 3     Koregaon Park  3 bhk    3.0       1659  210.00    3
# 4      Sinhgad Road  3 bhk    3.0       1450   78.00    3
# ...             ...    ...    ...        ...     ...  ...
# 1624   Sinhgad Road  2 bhk    2.0       1175   73.50    2
# 1625  Koregaon Park  2 bhk    2.0       1425   80.00    2
# 1626       Swargate  1 bhk    1.0       1200   20.00    1
# 1627    Karve Nagar  3 bhk    3.0       1200   56.12    3
# 1628    Karve Nagar  2 bhk    2.0       1255   67.00    2
#
# [1616 rows x 6 columns]

# %%
df['bhk'].unique()
# Out:
# array([ 2,  3,  1,  4,  5, 10,  6,  7,  8, 11,  9])

# %%
df['total_sqft'].unique()
# Out:
# array(['640', '690-720 ', '688-693 ', '1659', '1450', '1300', '850-950 ',
#        '1080', '650-750 ', '645-716 ', '346-384 ', '627-628 ', '573-606 ',
#        '850', '660', '500', '1140', '1020', '905', '1800', '1050', '2100',
#        '607', '605', '1620', '6000', '680', '865-1168 ', '350', '970',
#        '750', '1200', '450', '550', '635', '915', '460', '608', '1000',
#        '580', '1600', '950', '530', '525', '400', '820', '1109', '570',
#        '975', '633', '2500', '2600', '625', '1170', '2269', '2639', '620',
#        '667', '900', '2710', '1090', '601', '380', '930', '715', '420',
#        '2400', '494', '860', '600', '1250', '9440', '1270', '1610',
#        '5500', '2000', '2300', '1185', '10000', '1180', '1100', '1079',
#        '3000', '1500', '6280', '1054', '504', '1743.75', '661', '305',
#        '1431.6', '757', '835', '926', '914', '700', '822', '253', '1060',
#        '506', '720', '733', '800', '3065', '470', '718', '2308', '810',
# ...

# %%
#TO CHANGE RANGE VALUES TO A SINGLE NMBER. WE FIND AVRG

# %%
def is_float(x):
    try:
      float(x)
    except:
      return False
    return True

# %%
df[~df['total_sqft'].apply(is_float)]       #data which are not uniform
# Out:
#            location   size  Baths   total_sqft    price  bhk
# 1               Sus  2 bhk    2.0     690-720    45.000    2
# 2         Tathawade  2 bhk    2.0     688-693    60.000    2
# 6         Bibwewadi  2 bhk    2.0     850-950    50.000    2
# 8        Dhankawadi  3 bhk    3.0     850-950    87.500    3
# 9        Dhankawadi  2 bhk    2.0     650-750    67.500    2
# 10        Hinjewadi  2 bhk    2.0     645-716    59.430    2
# 11        Hinjewadi  1 bhk    1.0     346-384    37.000    1
# 12            Moshi  2 bhk    2.0     627-628    72.000    2
# 13            Baner  2 bhk    2.0     573-606    69.000    2
# 28        Bibwewadi  2 bhk    2.0    865-1168   105.500    2
# 151         Bavdhan  4 bhk    4.0    1175-1748  106.000    4
# 152           Wakad  4 bhk    4.0    1309-1431  250.000    4
# 237        Hadapsar  2 bhk    2.0      619-726   55.000    2
# 238        Hadapsar  1 bhk    1.0      432-497   34.500    1
# ...

# %%
def convert_sqft_to_num(x):
    tokens=x.split("-")
    if len(tokens)==2:
      return (float(tokens[0])+float(tokens[1]))/2
    try:
      return float(x)
    except:
        return None

# %%
df1=df.copy()
df1['total_sqft']=df1['total_sqft'].apply(convert_sqft_to_num)
df1.head()
# Out:
#         location   size  Baths  total_sqft   price  bhk
# 0        Bavdhan  2 bhk    2.0       640.0   55.96    2
# 1            Sus  2 bhk    2.0       705.0   45.00    2
# 2      Tathawade  2 bhk    2.0       690.5   60.00    2
# 3  Koregaon Park  3 bhk    3.0      1659.0  210.00    3
# 4   Sinhgad Road  3 bhk    3.0      1450.0   78.00    3

# %%
#So by this step we have cleaned the total_sqft column

# %%
df2=df1.copy()
df2['price_per_sqft']=df2['price']*100000/df2['total_sqft']
df2.head()
# Out:
#         location   size  Baths  total_sqft   price  bhk  price_per_sqft
# 0        Bavdhan  2 bhk    2.0       640.0   55.96    2     8743.750000
# 1            Sus  2 bhk    2.0       705.0   45.00    2     6382.978723
# 2      Tathawade  2 bhk    2.0       690.5   60.00    2     8689.355539
# 3  Koregaon Park  3 bhk    3.0      1659.0  210.00    3    12658.227848
# 4   Sinhgad Road  3 bhk    3.0      1450.0   78.00    3     5379.310345

# %%
len(df2.location.unique())
# Out:
# 43

# %%
df2.location=df2.location.apply(lambda x: x.strip())
location_stats=df2.groupby('location')['location'].agg('count')
location_stats
# Out:
# location
# AB Chowk                 30
# Amanora Town             21
# Amanora town              2
# Ambegaon                 24
# Balaji Nagar             41
# Baner                    45
# Bavdhan                   3
# Bibwewadi               242
# Budhwar Peth             11
# Bund Garden              11
# Camp                     11
# Deccan Gymkhana          11
# Dhankawadi              197
# FC Road                  32
# Hadapsar                 87
# Hinjewadi                 2
# Kanchan Nagari            1
# Karve Nagar              71
# Katraj                  198
# Kondhwa                  31
# Koregaon Park           125
# Kothrud                  10
# Kundalahalli              1
# Mangdewadi                1
# Manjri                    1
# Market yard              10
# Meera nagar               2
# Model colony              8
# Mohan Nagar               1
# Moshi                     1
# Padmavati                13
# Pune Railway Station     10
# ...

# %%
#If less than 10 values are there all those localities where classified into other location(feature engineering)

# %%
len(location_stats[location_stats<=10])
# Out:
# 22

# %%
location_stats_less_than_10=location_stats[location_stats<=10]
location_stats_less_than_10
# Out:
# location
# Amanora town             2
# Bavdhan                  3
# Hinjewadi                2
# Kanchan Nagari           1
# Kothrud                 10
# Kundalahalli             1
# Mangdewadi               1
# Manjri                   1
# Market yard             10
# Meera nagar              2
# Model colony             8
# Mohan Nagar              1
# Moshi                    1
# Pune Railway Station    10
# Sahakar Nagar           10
# Samarth Nagar            1
# Shivraj Nagar            1
# Sus                      2
# Tathawade                1
# Vighnaharta Nagar        1
# Vitthal nagar            1
# Wakad                    1
# Name: location, dtype: int64

# %%
len(df2.location.unique())
# Out:
# 43

# %%
df2.location=df2.location.apply(lambda x: 'other' if x in location_stats_less_than_10 else x)
len(df2.location.unique())
# Out:
# 22

# %%
df2.head(10)
# Out:
#         location   size  Baths  total_sqft   price  bhk  price_per_sqft
# 0          other  2 bhk    2.0       640.0   55.96    2     8743.750000
# 1          other  2 bhk    2.0       705.0   45.00    2     6382.978723
# 2          other  2 bhk    2.0       690.5   60.00    2     8689.355539
# 3  Koregaon Park  3 bhk    3.0      1659.0  210.00    3    12658.227848
# 4   Sinhgad Road  3 bhk    3.0      1450.0   78.00    3     5379.310345
# 5  Koregaon Park  2 bhk    2.0      1300.0  100.00    2     7692.307692
# 6      Bibwewadi  2 bhk    2.0       900.0   50.00    2     5555.555556
# 7  Koregaon Park  2 bhk    2.0      1080.0   95.00    2     8796.296296
# 8     Dhankawadi  3 bhk    3.0       900.0   87.50    3     9722.222222
# 9     Dhankawadi  2 bhk    2.0       700.0   67.50    2     9642.857143

# %%
df2.shape
# Out:
# (1616, 7)

# %%
df3=df2[~(df2.total_sqft/df2.bhk<300)]

# %%
df3.shape
# Out:
# (1533, 7)

# %%
df3.price_per_sqft.describe()
# Out:
# count     1533.000000
# mean      6610.855214
# std       3345.276378
# min        371.428571
# 25%       4444.444444
# 50%       5681.818182
# 75%       7550.200803
# max      30000.000000
# Name: price_per_sqft, dtype: float64

# %%
def remove_pps_outliers(df):
  df_out=pd.DataFrame()
  for key, subdf in df.groupby('location'):
      m=np.mean(subdf.price_per_sqft)
      sd=np.std(subdf.price_per_sqft)
      reduced_df=subdf[(subdf.price_per_sqft>(m-sd)) & (subdf.price_per_sqft<=(m+sd))]
      df_out=pd.concat([df_out,reduced_df],ignore_index=True)
  return df_out
df4=remove_pps_outliers(df3)
df4.shape
# Out:
# (1208, 7)

# %%
def plot_scatter_chart(df,location):
  bhk2=df[(df.location==location) & (df.bhk==2)]
  bhk3=df[(df.location==location) & (df.bhk==3)]
  plt.rcParams['figure.figsize']=(10,10)
  plt.scatter(bhk2.total_sqft,bhk2.price,color='red',label='2 BHK',s=50)
  plt.scatter(bhk3.total_sqft,bhk3.price,marker='+',color='green',label='3 BHK',s=70)
  plt.xlabel("Total Square Feet Area")
  plt.ylabel("Price ")
  plt.legend()
plt.figure(figsize=(8,6))
plot_scatter_chart(df4,"Bibwewadi")

# %%
def remove_bhk_outliers(df):
  exclude_indices=np.array([])
  for location, location_df in df.groupby('location'):
      bhk_stats={}
  for bhk,bhk_df in location_df.groupby('bhk'):
    bhk_stats[bhk]={
        'mean':np.mean(bhk_df.price_per_sqft),
        'std':np.std(bhk_df.price_per_sqft),
        'count':bhk_df.shape[0]
    }
  for bhk,bhk_df in location_df.groupby('bhk'):
    stats=bhk_stats.get(bhk-1)
    if stats and stats['count']>5:
      exclude_indices=np.append(exclude_indices,bhk_df[bhk_df.price_per_sqft<(stats['mean'])].index.values)
  return df.drop(exclude_indices,axis='index')
df5=remove_bhk_outliers(df4)
df5.shape
# Out:
# (1200, 7)

# %%
plot_scatter_chart(df5,"Bibwewadi")

# %%
import matplotlib
plt.figure(figsize=(8,6))
matplotlib.rcParams['figure.figsize']=(20,10)
plt.hist(df5.price_per_sqft,rwidth=0.8)
plt.xlabel("Price Per Square Feet")
plt.ylabel("Count")
# Out:
# Text(0, 0.5, 'Count')

# %%
df5.Baths.unique()
# Out:
# array([2., 1., 3., 4., 5., 7., 6., 8., 9.])

# %%
plt.figure(figsize=(8,6))
plt.hist(df5.Baths,rwidth=0.9,color='green')
plt.xlabel('Number of Bathrooms')
plt.ylabel('Count')
plt.title('Histogram of Number of Bathrooms')
# Out:
# Text(0.5, 1.0, 'Histogram of Number of Bathrooms')

# %%
df5.corr()
# Out:
# <ipython-input-135-d0269aa5c0fc>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df5.corr()
#                    Baths  total_sqft     price       bhk  price_per_sqft
# Baths           1.000000    0.814304  0.717932  0.918467        0.123150
# total_sqft      0.814304    1.000000  0.904322  0.789651        0.134791
# price           0.717932    0.904322  1.000000  0.655670        0.479145
# bhk             0.918467    0.789651  0.655670  1.000000        0.055326
# price_per_sqft  0.123150    0.134791  0.479145  0.055326        1.000000

# %%
plt.figure(figsize=(8, 6))
sns.heatmap(df5.corr())
# Out:
# <ipython-input-136-f7a055b4eb9f>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df5.corr())
# <Axes: >

# %%
plt.figure(figsize=(8,6))
sns.countplot(x='size',data=df5,color='blue')
plt.title('Count Plot of Size')
# Out:
# Text(0.5, 1.0, 'Count Plot of Size')

# %%
plt.figure(figsize=(10, 6))
sns.barplot(x='location', y='price', data=df5, palette='viridis')
plt.xticks(rotation=45, ha='right')
plt.xlabel('Location')
plt.ylabel('House Price (in lakhs)')
plt.title('House Prices in Pune by Location')
# Out:
# <ipython-input-138-6dff18cd8374>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='location', y='price', data=df5, palette='viridis')
# Text(0.5, 1.0, 'House Prices in Pune by Location')

# %%
df6=df5.drop(['size','price_per_sqft'],axis=1)
df6
# Out:
#       location  Baths  total_sqft    price  bhk
# 0     AB Chowk    2.0      1143.0   45.000    2
# 1     AB Chowk    1.0       600.0   38.000    1
# 2     AB Chowk    2.0       950.0   57.000    2
# 3     AB Chowk    2.0      1073.5   54.005    2
# 4     AB Chowk    3.0      1280.0   50.400    3
# ...        ...    ...         ...      ...  ...
# 1201     other    4.0      3670.0  300.000    4
# 1202     other    2.0       918.0   50.490    2
# 1205     other    2.0       793.0   45.000    2
# 1206     other    3.0      1710.0  107.000    3
# 1207     other    3.0      1680.0  150.000    3
#
# [1200 rows x 5 columns]

# %%
dummies=pd.get_dummies(df6[['location']],drop_first=True)

# %%
df7=pd.concat([dummies,df6],axis=1)

# %%
df7
# Out:
#       location_Amanora Town  location_Ambegaon  location_Balaji Nagar  \
# 0                         0                  0                      0
# 1                         0                  0                      0
# 2                         0                  0                      0
# 3                         0                  0                      0
# 4                         0                  0                      0
# ...                     ...                ...                    ...
# 1201                      0                  0                      0
# 1202                      0                  0                      0
# 1205                      0                  0                      0
# 1206                      0                  0                      0
# 1207                      0                  0                      0
#
#       location_Baner  location_Bibwewadi  location_Budhwar Peth  \
# ...

# %%
df8=df7.drop('location',axis=1)
df8
# Out:
#       location_Amanora Town  location_Ambegaon  location_Balaji Nagar  \
# 0                         0                  0                      0
# 1                         0                  0                      0
# 2                         0                  0                      0
# 3                         0                  0                      0
# 4                         0                  0                      0
# ...                     ...                ...                    ...
# 1201                      0                  0                      0
# 1202                      0                  0                      0
# 1205                      0                  0                      0
# 1206                      0                  0                      0
# 1207                      0                  0                      0
#
#       location_Baner  location_Bibwewadi  location_Budhwar Peth  \
# ...

# %%
df8.shape
# Out:
# (1200, 25)

# %%
x=df8.drop('price',axis=1)
x
# Out:
#       location_Amanora Town  location_Ambegaon  location_Balaji Nagar  \
# 0                         0                  0                      0
# 1                         0                  0                      0
# 2                         0                  0                      0
# 3                         0                  0                      0
# 4                         0                  0                      0
# ...                     ...                ...                    ...
# 1201                      0                  0                      0
# 1202                      0                  0                      0
# 1205                      0                  0                      0
# 1206                      0                  0                      0
# 1207                      0                  0                      0
#
#       location_Baner  location_Bibwewadi  location_Budhwar Peth  \
# ...

# %%
y=df8.price
y
# Out:
# 0        45.000
# 1        38.000
# 2        57.000
# 3        54.005
# 4        50.400
#          ...
# 1201    300.000
# 1202     50.490
# 1205     45.000
# 1206    107.000
# 1207    150.000
# Name: price, Length: 1200, dtype: float64

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.30,random_state=42)

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression()
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=model.predict(x_test)
y_pred
# Out:
# array([297.25898126,  78.33954619,  47.37878445,  67.6872878 ,
#         65.99587364,  59.56910898, 169.51081357,  37.21241626,
#         72.07020918, 105.72194166,  77.72439933,  35.29436564,
#         52.00128257,  72.34186431, 204.12615685,  77.72344086,
#         62.12402011,  69.49916362,  83.01171699, 163.96613164,
#         25.77204775,  56.5186861 ,  57.7161559 ,  32.53866322,
#         25.07971076, 138.8353361 ,  48.35349029,  27.67531683,
#         11.93124339,  76.13485245, 107.83398063,  74.83562837,
#         80.18734032, 227.35442209,  34.99925066,  40.71889976,
#         70.14787524,  81.52833187,  42.69694659,  43.72156482,
#         47.26617177,  68.55114198, 171.47402476,  31.46215621,
#        137.52043514,  22.31184666,  46.54161447,  45.74981294,
#         60.74606699, 266.10220304,  54.73563897,  59.95357577,
#         25.77204775,  41.93298522,  36.73178178,  37.69051817,
#        102.70723288,  92.84635037,  75.04394818,  28.08720866,
# ...

# %%
print("slope=",model.coef_)
# Out:
# slope= [ -2.20630699  -1.66600415   1.27700177   3.43944314  23.35848806
#   -1.83247333  -5.85372472   8.08512211  -8.14692519   8.35095096
#    3.08221401  11.39973931  12.56102076   6.70262569  15.09795516
#   17.54223556  39.09785537   8.19442256  11.86294345  -0.15169465
#   22.22841629  11.17622104   0.07689336 -16.55039589]

# %%
list(zip(x,model.coef_))
# Out:
# [('location_Amanora Town', -2.2063069907592685),
#  ('location_Ambegaon', -1.6660041524008404),
#  ('location_Balaji Nagar', 1.2770017708902912),
#  ('location_Baner', 3.439443138042856),
#  ('location_Bibwewadi', 23.358488059009883),
#  ('location_Budhwar Peth', -1.8324733274194691),
#  ('location_Bund Garden', -5.853724716317712),
#  ('location_Camp', 8.085122106006565),
#  ('location_Deccan Gymkhana', -8.14692518768344),
#  ('location_Dhankawadi', 8.350950955794293),
#  ('location_FC Road', 3.0822140137051903),
#  ('location_Hadapsar', 11.399739314948539),
#  ('location_Karve Nagar', 12.561020762114055),
#  ('location_Katraj', 6.702625688323543),
#  ('location_Kondhwa', 15.097955163831596),
#  ('location_Koregaon Park', 17.542235556247704),
#  ('location_Padmavati', 39.097855365070416),
#  ('location_Shivaji Nagar', 8.194422556898399),
#  ('location_Sinhgad Road', 11.862943452859845),
#  ('location_Swargate', -0.1516946547860646),
#  ('location_other', 22.22841628823023),
# ...

# %%
print("constant =",model.intercept_)
# Out:
# constant = -20.265008587190792

# %%
from sklearn.metrics import mean_absolute_error
print("mae=",mean_absolute_error(y_test,y_pred))
# Out:
# mae= 17.485689045033183

# %%
from sklearn.metrics import mean_absolute_percentage_error
print("mape=",mean_absolute_percentage_error(y_test,y_pred))
# Out:
# mape= 0.2250018046269033

# %%
from sklearn.metrics import mean_squared_error
print("mse=",mean_squared_error(y_test,y_pred))
# Out:
# mse= 634.7821367102041

# %%
mse=mean_squared_error(y_test,y_pred)
rmse=np.sqrt(mse)
rmse
# Out:
# 25.194883145396886

# %%
from sklearn.metrics import r2_score
print("r2_score=",r2_score(y_pred,y_test))
# Out:
# r2_score= 0.8067878738228691

# %%
df_results = pd.DataFrame({'Actual': y_test, 'Predicted': y_pred})
df_results
# Out:
#       Actual   Predicted
# 1181  280.00  297.258981
# 865    47.00   78.339546
# 101    57.00   47.378784
# 439    82.00   67.687288
# 58     94.00   65.995874
# ...      ...         ...
# 47     62.00   54.846337
# 318    82.50   79.878994
# 106    67.00   75.847651
# 798   105.00   63.422235
# 55     43.25   54.846337
#
# [360 rows x 2 columns]

# %%
plt.figure(figsize=(8,6))
plt.scatter(y_test, y_pred, alpha=0.5)
plt.title('Actual vs Predicted Values')
plt.xlabel('Actual Values')
plt.ylabel('Predicted Values')
plt.show()

# %%
plt.figure(figsize=(10,6))
residuals = y_test - y_pred
plt.scatter(y_test, residuals)
plt.axhline(y=0, color='red', linestyle='--')
plt.xlabel("Actual Values")
plt.ylabel("Residuals")
plt.title("Residual Plot")
plt.show()

# %%
from sklearn.tree import DecisionTreeRegressor
model1=DecisionTreeRegressor()

# %%
model1.fit(x_train,y_train)
# Out:
# DecisionTreeRegressor()

# %%
y_pred1=model.predict(x_test)
y_pred1
# Out:
# array([297.25898126,  78.33954619,  47.37878445,  67.6872878 ,
#         65.99587364,  59.56910898, 169.51081357,  37.21241626,
#         72.07020918, 105.72194166,  77.72439933,  35.29436564,
#         52.00128257,  72.34186431, 204.12615685,  77.72344086,
#         62.12402011,  69.49916362,  83.01171699, 163.96613164,
#         25.77204775,  56.5186861 ,  57.7161559 ,  32.53866322,
#         25.07971076, 138.8353361 ,  48.35349029,  27.67531683,
#         11.93124339,  76.13485245, 107.83398063,  74.83562837,
#         80.18734032, 227.35442209,  34.99925066,  40.71889976,
#         70.14787524,  81.52833187,  42.69694659,  43.72156482,
#         47.26617177,  68.55114198, 171.47402476,  31.46215621,
#        137.52043514,  22.31184666,  46.54161447,  45.74981294,
#         60.74606699, 266.10220304,  54.73563897,  59.95357577,
#         25.77204775,  41.93298522,  36.73178178,  37.69051817,
#        102.70723288,  92.84635037,  75.04394818,  28.08720866,
# ...

# %%
print("r2_score=",r2_score(y_pred1,y_test))
# Out:
# r2_score= 0.8067878738228691

# %%
plt.figure(figsize=(8,6))
plt.scatter(y_test, y_pred1, alpha=0.5)
plt.title('Actual vs Predicted Values')
plt.xlabel('Actual Values')
plt.ylabel('Predicted Values')
plt.show()

# %%
plt.figure(figsize=(10,6))
residuals = y_test - y_pred1
plt.scatter(y_test, residuals)
plt.axhline(y=0, color='red', linestyle='--')
plt.xlabel("Actual Values")
plt.ylabel("Residuals")
plt.title("Residual Plot")
plt.show()
